# %%
# %pip install -q minigrid gymnasium transformers accelerate torch sentencepiece
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from pathlib import Path
import time
from datetime import datetime, timezone
from collections import deque

import matplotlib.pyplot as plt
import pandas as pd
import gymnasium as gym
from minigrid.core.actions import Actions
from minigrid.wrappers import FullyObsWrapper
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
MODEL_CANDIDATES = [
    # "Qwen/Qwen2.5-3B-Instruct",
    "Qwen/Qwen2.5-7B-Instruct",
]
MAX_NEW_TOKENS = 16
TEMPERATURE = 0.0
MOCK_MODE = False
HISTORY_WINDOW = 3
ENVIRONMENTS = [
    "MiniGrid-LavaGapS7-v0",
    "MiniGrid-BlockedUnlockPickup-v0",
    "MiniGrid-DoorKey-5x5-v0",
    "MiniGrid-Empty-8x8-v0",
]
N_EPISODES_LIST = (10,)
MAX_STEPS_LIST = (50, 100)
OUTPUT_ROOT = "CS 228/outputs"
RUN_TAG = "bot_sweep"

# %%
from dataclasses import dataclass

@dataclass
class ThoughtTemplate:
    name: str
    description: str
    reasoning_pattern: str
    usage_count: int = 0
    success_rate: float = 0.0

class MetaBuffer:
    def __init__(self):
        self.templates = {}
        self._initialize_default_templates()

    def _initialize_default_templates(self):
        self.add_template(ThoughtTemplate(
            name="Direct Navigation",
            description="Moving towards a visible target in an empty space.",
            reasoning_pattern="1. Locate target coordinates. 2. Identify relative direction. 3. Align orientation. 4. Move forward."
        ))
        self.add_template(ThoughtTemplate(
            name="Obstacle Avoidance",
            description="Navigating around walls or closed doors.",
            reasoning_pattern="1. Identify blocking object. 2. Scan for open path. 3. Plan detour. 4. Execute lateral move."
        ))

    def add_template(self, template: ThoughtTemplate):
        self.templates[template.name] = template

    def retrieve(self, problem_description: str) -> ThoughtTemplate:
        if "wall" in problem_description.lower() or "door" in problem_description.lower():
            return self.templates["Obstacle Avoidance"]
        return self.templates["Direct Navigation"]

class ProblemDistiller:
    @staticmethod
    def distill(obs_text: str) -> str:
        return obs_text

class BufferManager:
    def __init__(self):
        self.meta_buffer = MetaBuffer()
        self.thought_history = deque(maxlen=50)

    def get_reasoning_aid(self, distilled_problem: str) -> str:
        template = self.meta_buffer.retrieve(distilled_problem)
        return f"[TEMPLATE: {template.name}]\n{template.reasoning_pattern}"

# %%
class MinigridTextWrapper:
    def __init__(self, env_id, render_mode=None):
        self.env = gym.make(env_id, render_mode=render_mode)
        self.env = FullyObsWrapper(self.env)
        self.action_map = {
            "turn_left": Actions.left,
            "turn_right": Actions.right,
            "forward": Actions.forward,
            "pickup": Actions.pickup,
            "drop": Actions.drop,
            "toggle": Actions.toggle,
            "done": Actions.done
        }

    def _base_env(self):
        return self.env.unwrapped

    def _find_goal_pos(self):
        base = self._base_env()
        grid = base.grid
        for x in range(grid.width):
            for y in range(grid.height):
                cell = grid.get(x, y)
                if cell is not None and getattr(cell, "type", None) == "goal":
                    return (int(x), int(y))
        return None

    def get_text_obs(self, obs):
        base = self._base_env()

        if hasattr(base, "agent_pos") and base.agent_pos is not None:
            ax, ay = int(base.agent_pos[0]), int(base.agent_pos[1])
            agent_pos = (ax, ay)
            agent_pos_text = f"[{ax}, {ay}]"
        else:
            agent_pos = None
            agent_pos_text = "None"

        agent_dir = int(base.agent_dir) if hasattr(base, "agent_dir") else None
        goal_pos = self._find_goal_pos()
        goal_pos_text = f"[{goal_pos[0]}, {goal_pos[1]}]" if goal_pos is not None else "None"

        dirs = ["right", "down", "left", "up"]
        facing = dirs[agent_dir] if agent_dir is not None and 0 <= agent_dir < 4 else "unknown"
        desc = f"Agent is at {agent_pos_text} facing {facing}. Goal is at {goal_pos_text}."

        front_obj = None
        if hasattr(base, "front_pos") and hasattr(base, "grid"):
            fx, fy = int(base.front_pos[0]), int(base.front_pos[1])
            front_obj = base.grid.get(fx, fy)

        if front_obj:
            desc += f" In front of you is a {front_obj.type}."
        else:
            desc += " The path in front is clear."

        return desc

    def reset(self):
        reset_out = self.env.reset()
        if isinstance(reset_out, tuple) and len(reset_out) == 2:
            obs, _ = reset_out
        else:
            obs = reset_out
        return self.get_text_obs(obs)

    def step(self, action_str):
        action = self.action_map.get(action_str.lower(), Actions.forward)
        obs, reward, terminated, truncated, info = self.env.step(action)
        done = terminated or truncated
        return self.get_text_obs(obs), reward, done, info

# %%
class LLMClient:
    def __init__(self, model_name="Qwen/Qwen2.5-3B-Instruct", max_new_tokens=16, temperature=0.0, mock=False):
        self.model_name = model_name
        self.max_new_tokens = max_new_tokens
        self.temperature = temperature
        self.mock = mock
        self.total_tokens = 0
        self.total_latency = 0
        self.model = None
        self.tokenizer = None

        if not self.mock:
            self._load_hf_model()

    def _load_hf_model(self):
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_name, trust_remote_code=True)
        self.model = AutoModelForCausalLM.from_pretrained(
            self.model_name,
            torch_dtype="auto",
            device_map="auto",
            trust_remote_code=True,
        )
        self.model.eval()
        print(f"Loaded model: {self.model_name}")

    def query(self, system_prompt, user_prompt):
        start_time = time.time()

        if self.mock:
            response = self._mock_logic(user_prompt)
            tokens = len(system_prompt + user_prompt) // 4
        else:
            messages = [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt},
            ]
            prompt = self.tokenizer.apply_chat_template(
                messages,
                tokenize=False,
                add_generation_prompt=True,
            )

            inputs = self.tokenizer(prompt, return_tensors="pt")
            inputs = {k: v.to(self.model.device) for k, v in inputs.items()}
            input_tokens = inputs["input_ids"].shape[-1]

            gen_kwargs = {
                "max_new_tokens": self.max_new_tokens,
                "do_sample": self.temperature > 0,
                "pad_token_id": self.tokenizer.eos_token_id,
            }
            if self.temperature > 0:
                gen_kwargs["temperature"] = self.temperature
                gen_kwargs["top_p"] = 0.9

            with torch.no_grad():
                outputs = self.model.generate(**inputs, **gen_kwargs)

            generated = outputs[0][input_tokens:]
            response = self.tokenizer.decode(generated, skip_special_tokens=True).strip()
            tokens = int(generated.shape[-1])

        latency = time.time() - start_time
        self.total_tokens += tokens
        self.total_latency += latency

        return response, tokens, latency

    @staticmethod
    def _extract_state_from_prompt(prompt):
        import re

        coord_pat = r"[\[\(]\s*(\d+)\s*,\s*(\d+)\s*[\]\)]"
        pos_match = re.search(rf"Agent is at {coord_pat} facing (\w+)", prompt)
        goal_match = re.search(rf"Goal is at {coord_pat}", prompt)

        if not pos_match or not goal_match:
            return None

        ax, ay = int(pos_match.group(1)), int(pos_match.group(2))
        face = pos_match.group(3)
        gx, gy = int(goal_match.group(1)), int(goal_match.group(2))
        return ax, ay, face, gx, gy

    @staticmethod
    def _mock_policy_action(ax, ay, face, gx, gy):
        if face == "right":
            if gx > ax:
                return "forward"
            return "turn_left" if gy < ay else "turn_right"
        if face == "left":
            if gx < ax:
                return "forward"
            return "turn_right" if gy < ay else "turn_left"
        if face == "up":
            if gy < ay:
                return "forward"
            return "turn_right" if gx > ax else "turn_left"
        if face == "down":
            if gy > ay:
                return "forward"
            return "turn_left" if gx > ax else "turn_right"
        return "forward"

    def _mock_logic(self, prompt):
        state = self._extract_state_from_prompt(prompt)
        if state is None:
            return "forward"

        ax, ay, face, gx, gy = state
        return self._mock_policy_action(ax, ay, face, gx, gy)

# %%
class BoTAgent:
    def __init__(self, llm_client, buffer_manager, use_history=True, history_window=3):
        self.llm = llm_client
        self.buffer_manager = buffer_manager
        self.use_history = use_history
        self.history_window = history_window
        self.memory = []

    @staticmethod
    def _parse_action(response_text):
        action = response_text.strip().lower()
        if "forward" in action:
            return "forward"
        if "left" in action:
            return "turn_left"
        if "right" in action:
            return "turn_right"
        if "toggle" in action:
            return "toggle"
        if "pickup" in action:
            return "pickup"
        if "drop" in action:
            return "drop"
        return "forward"

    def act(self, observation):
        distilled = ProblemDistiller.distill(observation)
        aid = self.buffer_manager.get_reasoning_aid(distilled)

        system_prompt = "You are a MiniGrid navigation agent. Choose exactly one action token: forward, turn_left, turn_right, toggle, pickup, drop."
        history_context = self.memory[-self.history_window:] if self.use_history else []
        user_prompt = (
            f"Current Obs: {observation}\n"
            f"{aid}\n"
            f"Recent history: {history_context}\n"
            "Return only one action token."
        )

        response, tokens, latency = self.llm.query(system_prompt, user_prompt)
        action = self._parse_action(response)

        self.memory.append((observation, action))
        return action

# %%
def _run_single_episode(env, agent, max_steps):
    obs = env.reset()
    done = False
    steps = 0
    total_reward = 0.0

    while not done and steps < max_steps:
        action = agent.act(obs)
        obs, reward, done, info = env.step(action)
        total_reward += reward
        steps += 1

    success = total_reward > 0
    return success, steps, total_reward


def _build_episode_row(
    env_id,
    episode,
    policy,
    use_history,
    history_window,
    max_steps,
    model_name,
    mock,
    success,
    steps,
    reward,
    tokens,
    latency,
):
    return {
        "env": env_id,
        "episode": episode,
        "policy": policy,
        "use_history": use_history,
        "history_window": history_window if use_history else 0,
        "max_steps": max_steps,
        "model": model_name,
        "mock": mock,
        "success": success,
        "steps": steps,
        "reward": reward,
        "tokens": tokens,
        "time": latency,
    }


def run_experiment(
    env_id,
    n_episodes=10,
    model_name="Qwen/Qwen2.5-3B-Instruct",
    mock=False,
    max_steps=100,
    use_history=True,
    history_window=3,
    policy_label=None,
):
    results = []
    llm = LLMClient(model_name=model_name, mock=mock)
    buffer_mgr = BufferManager()
    env = MinigridTextWrapper(env_id)

    policy = policy_label or ("history" if use_history else "reactive")
    print(
        f"Running {n_episodes} episodes on {env_id} | policy={policy} | "
        f"max_steps={max_steps} | model={model_name} | mock={mock}"
    )

    for i in range(n_episodes):
        agent = BoTAgent(
            llm,
            buffer_mgr,
            use_history=use_history,
            history_window=history_window,
        )

        success, steps, total_reward = _run_single_episode(
            env=env,
            agent=agent,
            max_steps=max_steps,
        )

        results.append(
            _build_episode_row(
                env_id=env_id,
                episode=i,
                policy=policy,
                use_history=use_history,
                history_window=history_window,
                max_steps=max_steps,
                model_name=model_name,
                mock=mock,
                success=success,
                steps=steps,
                reward=total_reward,
                tokens=llm.total_tokens,
                latency=llm.total_latency,
            )
        )
        print(f"  Ep {i}: Success={success}, Steps={steps}, Reward={total_reward:.3f}")

    return pd.DataFrame(results)


def _resolve_env_id(candidates):
    """Return the first available env_id from a candidate list."""
    for env_id in candidates:
        try:
            test_env = gym.make(env_id)
            test_env.close()
            return env_id
        except Exception:
            continue
    return None


def _default_env_candidate_map():
    return {
        "MiniGrid-LavaGapS7-v0": ["MiniGrid-LavaGapS7-v0"],
        "MiniGrid-BlockedUnlockPickup-v0": [
            "MiniGrid-BlockedUnlockPickup-v0",
            "MiniGrid-UnlockPickup-v0",
        ],
        "MiniGrid-DoorKey-5x5-v0": ["MiniGrid-DoorKey-5x5-v0"],
        "MiniGrid-Empty-8x8-v0": ["MiniGrid-Empty-8x8-v0"],
    }


def _resolve_environment_pairs(environments, env_candidate_map=None):
    env_candidate_map = env_candidate_map or _default_env_candidate_map()
    resolved_envs = []

    for env_name in environments:
        candidates = env_candidate_map.get(env_name, [env_name])
        resolved = _resolve_env_id(candidates)
        if resolved is None:
            print(f"Skipping {env_name}: no available env id from {candidates}")
            continue
        resolved_envs.append((env_name, resolved))

    return resolved_envs


def _empty_errors_df():
    return pd.DataFrame(
        columns=["model", "env", "resolved_env", "n_episodes_setting", "max_steps", "error"]
    )


def _build_summary_frame(all_results):
    if all_results.empty:
        return pd.DataFrame(
            columns=["model", "env", "n_episodes_setting", "max_steps", "success", "steps", "reward", "tokens", "time"]
        )

    return all_results.groupby(
        ["model", "env", "n_episodes_setting", "max_steps"], as_index=False
    )[["success", "steps", "reward", "tokens", "time"]].mean()


def _run_single_condition(
    model_name,
    canonical_name,
    resolved_env_id,
    n_episodes,
    max_steps,
    history_window,
    mock,
    policy_label,
):
    try:
        df = run_experiment(
            env_id=resolved_env_id,
            n_episodes=n_episodes,
            model_name=model_name,
            mock=mock,
            max_steps=max_steps,
            use_history=True,
            history_window=history_window,
            policy_label=policy_label,
        )
        df["env"] = canonical_name
        df["resolved_env"] = resolved_env_id
        df["n_episodes_setting"] = int(n_episodes)
        return df, None
    except Exception as e:
        error_row = {
            "model": model_name,
            "env": canonical_name,
            "resolved_env": resolved_env_id,
            "n_episodes_setting": int(n_episodes),
            "max_steps": int(max_steps),
            "error": str(e),
        }
        return None, error_row


def build_run_config(
    model_candidates,
    mock_mode,
    history_window,
    environments,
    n_episodes_list,
    max_steps_list,
):
    return {
        "model_candidates": list(model_candidates),
        "mock_mode": bool(mock_mode),
        "history_window": int(history_window),
        "environments": list(environments),
        "n_episodes_list": list(n_episodes_list),
        "max_steps_list": list(max_steps_list),
    }


def run_bot_experiments(
    model_names,
    environments,
    n_episodes_list,
    max_steps_list,
    history_window=3,
    mock=True,
    return_errors=False,
):
    resolved_envs = _resolve_environment_pairs(environments)
    policy_label = f"BoT_history_k{history_window}"

    frames = []
    errors = []

    total_runs = len(model_names) * len(resolved_envs) * len(n_episodes_list) * len(max_steps_list)
    current_run = 0

    for model_name in model_names:
        for canonical_name, resolved_env_id in resolved_envs:
            for n_episodes in n_episodes_list:
                for max_steps in max_steps_list:
                    current_run += 1
                    print(
                        f"\n[{current_run}/{total_runs}] Running: {model_name} | {canonical_name} "
                        f"| n_episodes={n_episodes} | max_steps={max_steps}"
                    )

                    condition_df, error_row = _run_single_condition(
                        model_name=model_name,
                        canonical_name=canonical_name,
                        resolved_env_id=resolved_env_id,
                        n_episodes=n_episodes,
                        max_steps=max_steps,
                        history_window=history_window,
                        mock=mock,
                        policy_label=policy_label,
                    )

                    if condition_df is not None:
                        frames.append(condition_df)
                    if error_row is not None:
                        errors.append(error_row)
                        print(f"Error: {error_row['error']}")

    all_results = pd.concat(frames, ignore_index=True) if frames else pd.DataFrame()
    errors_df = pd.DataFrame(errors) if errors else _empty_errors_df()

    if return_errors:
        return all_results, errors_df
    return all_results


def save_run_outputs(
    all_results,
    run_errors=None,
    output_root="CS 228/outputs",
    run_tag="bot_sweep",
    config=None,
):
    """Minimal structured save: episodes/summary/errors + config/metadata."""
    run_id = f"{datetime.now(timezone.utc).strftime('%Y%m%d_%H%M%S')}_{run_tag}"
    run_dir = Path(output_root) / run_id
    run_dir.mkdir(parents=True, exist_ok=True)

    episodes_path = run_dir / "episodes.csv"
    summary_path = run_dir / "summary.csv"
    errors_path = run_dir / "errors.csv"
    config_path = run_dir / "config.json"
    metadata_path = run_dir / "metadata.json"

    all_results.to_csv(episodes_path, index=False)
    summary = _build_summary_frame(all_results)
    summary.to_csv(summary_path, index=False)

    if run_errors is None:
        run_errors = _empty_errors_df()
    run_errors.to_csv(errors_path, index=False)

    if config is None:
        config = {}
    with config_path.open("w", encoding="utf-8") as f:
        json.dump(config, f, indent=2)

    metadata = {
        "run_id": run_id,
        "saved_at": datetime.now(timezone.utc).isoformat(),
        "rows": int(len(all_results)),
        "errors": int(len(run_errors)),
    }
    with metadata_path.open("w", encoding="utf-8") as f:
        json.dump(metadata, f, indent=2)

    return {
        "run_id": run_id,
        "run_dir": str(run_dir),
        "episodes_path": str(episodes_path),
        "summary_path": str(summary_path),
        "errors_path": str(errors_path),
        "config_path": str(config_path),
        "metadata_path": str(metadata_path),
    }

# %%
all_results, run_errors = run_bot_experiments(
    model_names=MODEL_CANDIDATES,
    environments=ENVIRONMENTS,
    n_episodes_list=N_EPISODES_LIST,
    max_steps_list=MAX_STEPS_LIST,
    history_window=HISTORY_WINDOW,
    mock=MOCK_MODE,
    return_errors=True,
)

run_config = build_run_config(
    model_candidates=MODEL_CANDIDATES,
    mock_mode=MOCK_MODE,
    history_window=HISTORY_WINDOW,
    environments=ENVIRONMENTS,
    n_episodes_list=N_EPISODES_LIST,
    max_steps_list=MAX_STEPS_LIST,
)

run_artifacts = save_run_outputs(
    all_results=all_results,
    run_errors=run_errors,
    output_root=OUTPUT_ROOT,
    run_tag=RUN_TAG,
    config=run_config,
)

print("\nExperiment Results Summary")
print(f"Rows: {len(all_results)}")
print(f"Errors: {len(run_errors)}")
print(f"Saved to: {run_artifacts['run_dir']}")

display(all_results.head(10))
if not run_errors.empty:
    display(run_errors.head(10))
# Out:
# [1/8] Running: Qwen/Qwen2.5-7B-Instruct | MiniGrid-LavaGapS7-v0 | n_episodes=10 | max_steps=50
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.56G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Loaded model: Qwen/Qwen2.5-7B-Instruct
# Running 10 episodes on MiniGrid-LavaGapS7-v0 | policy=BoT_history_k3 | max_steps=50 | model=Qwen/Qwen2.5-7B-Instruct | mock=False
#   Ep 0: Success=False, Steps=15, Reward=0.000
#   Ep 1: Success=True, Steps=11, Reward=0.949
#   Ep 2: Success=True, Steps=15, Reward=0.931
#   Ep 3: Success=False, Steps=15, Reward=0.000
#   Ep 4: Success=True, Steps=11, Reward=0.949
#   Ep 5: Success=True, Steps=15, Reward=0.931
#   Ep 6: Success=True, Steps=11, Reward=0.949
#   Ep 7: Success=False, Steps=50, Reward=0.000
#   Ep 8: Success=True, Steps=11, Reward=0.949
#   Ep 9: Success=True, Steps=15, Reward=0.931
#
# [2/8] Running: Qwen/Qwen2.5-7B-Instruct | MiniGrid-LavaGapS7-v0 | n_episodes=10 | max_steps=100
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loaded model: Qwen/Qwen2.5-7B-Instruct
# Running 10 episodes on MiniGrid-LavaGapS7-v0 | policy=BoT_history_k3 | max_steps=100 | model=Qwen/Qwen2.5-7B-Instruct | mock=False
#   Ep 0: Success=False, Steps=100, Reward=0.000
#   Ep 1: Success=False, Steps=100, Reward=0.000
#   Ep 2: Success=False, Steps=15, Reward=0.000
#   Ep 3: Success=True, Steps=15, Reward=0.931
#   Ep 4: Success=True, Steps=15, Reward=0.931
#   Ep 5: Success=False, Steps=100, Reward=0.000
#   Ep 6: Success=False, Steps=100, Reward=0.000
#   Ep 7: Success=False, Steps=100, Reward=0.000
#   Ep 8: Success=True, Steps=15, Reward=0.931
#   Ep 9: Success=False, Steps=100, Reward=0.000
#
# [3/8] Running: Qwen/Qwen2.5-7B-Instruct | MiniGrid-BlockedUnlockPickup-v0 | n_episodes=10 | max_steps=50
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loaded model: Qwen/Qwen2.5-7B-Instruct
# Running 10 episodes on MiniGrid-BlockedUnlockPickup-v0 | policy=BoT_history_k3 | max_steps=50 | model=Qwen/Qwen2.5-7B-Instruct | mock=False
#   Ep 0: Success=False, Steps=50, Reward=0.000
#   Ep 1: Success=False, Steps=50, Reward=0.000
#   Ep 2: Success=False, Steps=50, Reward=0.000
#   Ep 3: Success=False, Steps=50, Reward=0.000
#   Ep 4: Success=False, Steps=50, Reward=0.000
#   Ep 5: Success=False, Steps=50, Reward=0.000
#   Ep 6: Success=False, Steps=50, Reward=0.000
#   Ep 7: Success=False, Steps=50, Reward=0.000
#   Ep 8: Success=False, Steps=50, Reward=0.000
#   Ep 9: Success=False, Steps=50, Reward=0.000
#
# [4/8] Running: Qwen/Qwen2.5-7B-Instruct | MiniGrid-BlockedUnlockPickup-v0 | n_episodes=10 | max_steps=100
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loaded model: Qwen/Qwen2.5-7B-Instruct
# Running 10 episodes on MiniGrid-BlockedUnlockPickup-v0 | policy=BoT_history_k3 | max_steps=100 | model=Qwen/Qwen2.5-7B-Instruct | mock=False
#   Ep 0: Success=False, Steps=100, Reward=0.000
#   Ep 1: Success=False, Steps=100, Reward=0.000
#   Ep 2: Success=False, Steps=100, Reward=0.000
#   Ep 3: Success=False, Steps=100, Reward=0.000
#   Ep 4: Success=False, Steps=100, Reward=0.000
#   Ep 5: Success=False, Steps=100, Reward=0.000
#   Ep 6: Success=False, Steps=100, Reward=0.000
#   Ep 7: Success=False, Steps=100, Reward=0.000
#   Ep 8: Success=False, Steps=100, Reward=0.000
#   Ep 9: Success=False, Steps=100, Reward=0.000
#
# [5/8] Running: Qwen/Qwen2.5-7B-Instruct | MiniGrid-DoorKey-5x5-v0 | n_episodes=10 | max_steps=50
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loaded model: Qwen/Qwen2.5-7B-Instruct
# Running 10 episodes on MiniGrid-DoorKey-5x5-v0 | policy=BoT_history_k3 | max_steps=50 | model=Qwen/Qwen2.5-7B-Instruct | mock=False
#   Ep 0: Success=False, Steps=50, Reward=0.000
#   Ep 1: Success=False, Steps=50, Reward=0.000
#   Ep 2: Success=False, Steps=50, Reward=0.000
#   Ep 3: Success=False, Steps=50, Reward=0.000
#   Ep 4: Success=False, Steps=50, Reward=0.000
#   Ep 5: Success=False, Steps=50, Reward=0.000
#   Ep 6: Success=False, Steps=50, Reward=0.000
#   Ep 7: Success=False, Steps=50, Reward=0.000
#   Ep 8: Success=False, Steps=50, Reward=0.000
#   Ep 9: Success=False, Steps=50, Reward=0.000
#
# [6/8] Running: Qwen/Qwen2.5-7B-Instruct | MiniGrid-DoorKey-5x5-v0 | n_episodes=10 | max_steps=100
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loaded model: Qwen/Qwen2.5-7B-Instruct
# Running 10 episodes on MiniGrid-DoorKey-5x5-v0 | policy=BoT_history_k3 | max_steps=100 | model=Qwen/Qwen2.5-7B-Instruct | mock=False
#   Ep 0: Success=False, Steps=100, Reward=0.000
#   Ep 1: Success=False, Steps=100, Reward=0.000
#   Ep 2: Success=False, Steps=100, Reward=0.000
#   Ep 3: Success=False, Steps=100, Reward=0.000
#   Ep 4: Success=False, Steps=100, Reward=0.000
#   Ep 5: Success=False, Steps=100, Reward=0.000
#   Ep 6: Success=False, Steps=100, Reward=0.000
#   Ep 7: Success=False, Steps=100, Reward=0.000
#   Ep 8: Success=False, Steps=100, Reward=0.000
#   Ep 9: Success=False, Steps=100, Reward=0.000
#
# [7/8] Running: Qwen/Qwen2.5-7B-Instruct | MiniGrid-Empty-8x8-v0 | n_episodes=10 | max_steps=50
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loaded model: Qwen/Qwen2.5-7B-Instruct
# Running 10 episodes on MiniGrid-Empty-8x8-v0 | policy=BoT_history_k3 | max_steps=50 | model=Qwen/Qwen2.5-7B-Instruct | mock=False
#   Ep 0: Success=True, Steps=13, Reward=0.954
#   Ep 1: Success=True, Steps=13, Reward=0.954
#   Ep 2: Success=True, Steps=13, Reward=0.954
#   Ep 3: Success=True, Steps=13, Reward=0.954
#   Ep 4: Success=True, Steps=13, Reward=0.954
#   Ep 5: Success=True, Steps=13, Reward=0.954
#   Ep 6: Success=True, Steps=13, Reward=0.954
#   Ep 7: Success=True, Steps=13, Reward=0.954
#   Ep 8: Success=True, Steps=13, Reward=0.954
#   Ep 9: Success=True, Steps=13, Reward=0.954
#
# [8/8] Running: Qwen/Qwen2.5-7B-Instruct | MiniGrid-Empty-8x8-v0 | n_episodes=10 | max_steps=100
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loaded model: Qwen/Qwen2.5-7B-Instruct
# Running 10 episodes on MiniGrid-Empty-8x8-v0 | policy=BoT_history_k3 | max_steps=100 | model=Qwen/Qwen2.5-7B-Instruct | mock=False
#   Ep 0: Success=True, Steps=13, Reward=0.954
#   Ep 1: Success=True, Steps=13, Reward=0.954
#   Ep 2: Success=True, Steps=13, Reward=0.954
#   Ep 3: Success=True, Steps=13, Reward=0.954
#   Ep 4: Success=True, Steps=13, Reward=0.954
#   Ep 5: Success=True, Steps=13, Reward=0.954
#   Ep 6: Success=True, Steps=13, Reward=0.954
#   Ep 7: Success=True, Steps=13, Reward=0.954
#   Ep 8: Success=True, Steps=13, Reward=0.954
#   Ep 9: Success=True, Steps=13, Reward=0.954
#
# Experiment Results Summary
# Rows: 80
# Errors: 0
# Saved to: CS 228/outputs/20260308_152234_bot_sweep
#                      env  episode          policy  use_history  \
# 0  MiniGrid-LavaGapS7-v0        0  BoT_history_k3         True
# 1  MiniGrid-LavaGapS7-v0        1  BoT_history_k3         True
# 2  MiniGrid-LavaGapS7-v0        2  BoT_history_k3         True
# 3  MiniGrid-LavaGapS7-v0        3  BoT_history_k3         True
# 4  MiniGrid-LavaGapS7-v0        4  BoT_history_k3         True
# 5  MiniGrid-LavaGapS7-v0        5  BoT_history_k3         True
# 6  MiniGrid-LavaGapS7-v0        6  BoT_history_k3         True
# 7  MiniGrid-LavaGapS7-v0        7  BoT_history_k3         True
# 8  MiniGrid-LavaGapS7-v0        8  BoT_history_k3         True
# 9  MiniGrid-LavaGapS7-v0        9  BoT_history_k3         True
#
#    history_window  max_steps                     model   mock  success  steps  \
# 0               3         50  Qwen/Qwen2.5-7B-Instruct  False    False     15
# 1               3         50  Qwen/Qwen2.5-7B-Instruct  False     True     11
# 2               3         50  Qwen/Qwen2.5-7B-Instruct  False     True     15
# 3               3         50  Qwen/Qwen2.5-7B-Instruct  False    False     15
# 4               3         50  Qwen/Qwen2.5-7B-Instruct  False     True     11
# 5               3         50  Qwen/Qwen2.5-7B-Instruct  False     True     15
# 6               3         50  Qwen/Qwen2.5-7B-Instruct  False     True     11
# 7               3         50  Qwen/Qwen2.5-7B-Instruct  False    False     50
# 8               3         50  Qwen/Qwen2.5-7B-Instruct  False     True     11
# 9               3         50  Qwen/Qwen2.5-7B-Instruct  False     True     15
#
#      reward  tokens       time           resolved_env  n_episodes_setting
# 0  0.000000      40   1.855662  MiniGrid-LavaGapS7-v0                  10
# 1  0.949490      65   2.557904  MiniGrid-LavaGapS7-v0                  10
# 2  0.931122     101   3.562325  MiniGrid-LavaGapS7-v0                  10
# 3  0.000000     141   4.663614  MiniGrid-LavaGapS7-v0                  10
# 4  0.949490     166   5.361567  MiniGrid-LavaGapS7-v0                  10
# 5  0.931122     202   6.370946  MiniGrid-LavaGapS7-v0                  10
# 6  0.949490     227   7.067085  MiniGrid-LavaGapS7-v0                  10
# 7  0.000000     344  10.336405  MiniGrid-LavaGapS7-v0                  10
# 8  0.949490     369  11.038813  MiniGrid-LavaGapS7-v0                  10
# 9  0.931122     405  12.057340  MiniGrid-LavaGapS7-v0                  10

# %%
def _save_displayed_figure(fig, artifacts):
    if not artifacts:
        return None
    out_path = Path(artifacts["run_dir"]) / "overview.png"
    fig.savefig(out_path, dpi=150, bbox_inches="tight")
    return out_path


def _build_plot_inputs(all_results):
    success_pivot = all_results.groupby(["env", "model"])["success"].mean().unstack(fill_value=0)
    steps_pivot = all_results.groupby(["env", "model"])["steps"].mean().unstack(fill_value=0)
    maxstep_pivot = all_results.groupby(["max_steps", "env"])["success"].mean().unstack(fill_value=0)
    env_maxstep_pivot = all_results.groupby(["env", "max_steps"])["success"].mean().unstack(fill_value=0)
    return success_pivot, steps_pivot, maxstep_pivot, env_maxstep_pivot


def _draw_overview_figure(success_pivot, steps_pivot, maxstep_pivot, env_maxstep_pivot):
    fig, axes = plt.subplots(2, 2, figsize=(18, 12))

    success_pivot.plot(kind="bar", ax=axes[0, 0])
    axes[0, 0].set_title("Success Rate by Environment and Model")
    axes[0, 0].set_ylabel("Success Rate")
    axes[0, 0].set_ylim(0, 1)

    steps_pivot.plot(kind="bar", ax=axes[0, 1])
    axes[0, 1].set_title("Average Steps by Environment and Model")
    axes[0, 1].set_ylabel("Steps")

    maxstep_pivot.plot(marker="o", ax=axes[1, 0])
    axes[1, 0].set_title("Success vs Max Steps")
    axes[1, 0].set_xlabel("max_steps")
    axes[1, 0].set_ylabel("Success Rate")
    axes[1, 0].set_ylim(0, 1)

    env_maxstep_pivot.plot(kind="bar", ax=axes[1, 1])
    axes[1, 1].set_title("Success Rate by Environment (grouped by max_steps)")
    axes[1, 1].set_ylabel("Success Rate")
    axes[1, 1].set_ylim(0, 1)

    plt.tight_layout()
    return fig


if all_results.empty:
    print("No experiment results available to visualize.")
else:
    displayed_plot_paths = []

    success_pivot, steps_pivot, maxstep_pivot, env_maxstep_pivot = _build_plot_inputs(all_results)
    fig = _draw_overview_figure(success_pivot, steps_pivot, maxstep_pivot, env_maxstep_pivot)

    artifacts = globals().get("run_artifacts")
    saved_path = _save_displayed_figure(fig, artifacts)
    if saved_path is not None:
        displayed_plot_paths.append(str(saved_path))

    plt.show()

    if displayed_plot_paths:
        print("Saved displayed plots:")
        for p in displayed_plot_paths:
            print(f"- {p}")

    summary = all_results.groupby(["model", "env", "n_episodes_setting", "max_steps"])[
        ["success", "steps", "reward", "tokens", "time"]
    ].mean()
    display(summary)
# Out:
# Saved displayed plots:
# - CS 228/outputs/20260308_152234_bot_sweep/overview.png
#                                                                                        success  \
# model                    env                             n_episodes_setting max_steps
# Qwen/Qwen2.5-7B-Instruct MiniGrid-BlockedUnlockPickup-v0 10                 50             0.0
#                                                                             100            0.0
#                          MiniGrid-DoorKey-5x5-v0         10                 50             0.0
#                                                                             100            0.0
#                          MiniGrid-Empty-8x8-v0           10                 50             1.0
#                                                                             100            1.0
#                          MiniGrid-LavaGapS7-v0           10                 50             0.7
#                                                                             100            0.3
#
#                                                                                        steps  \
# model                    env                             n_episodes_setting max_steps
# Qwen/Qwen2.5-7B-Instruct MiniGrid-BlockedUnlockPickup-v0 10                 50          50.0
#                                                                             100        100.0
#                          MiniGrid-DoorKey-5x5-v0         10                 50          50.0
#                                                                             100        100.0
#                          MiniGrid-Empty-8x8-v0           10                 50          13.0
#                                                                             100         13.0
#                          MiniGrid-LavaGapS7-v0           10                 50          16.9
#                                                                             100         66.0
#
#                                                                                          reward  \
# model                    env                             n_episodes_setting max_steps
# Qwen/Qwen2.5-7B-Instruct MiniGrid-BlockedUnlockPickup-v0 10                 50         0.000000
#                                                                             100        0.000000
#                          MiniGrid-DoorKey-5x5-v0         10                 50         0.000000
#                                                                             100        0.000000
#                          MiniGrid-Empty-8x8-v0           10                 50         0.954297
#                                                                             100        0.954297
#                          MiniGrid-LavaGapS7-v0           10                 50         0.659133
#                                                                             100        0.279337
#
#                                                                                        tokens  \
# model                    env                             n_episodes_setting max_steps
# Qwen/Qwen2.5-7B-Instruct MiniGrid-BlockedUnlockPickup-v0 10                 50          712.7
#                                                                             100        1365.9
#                          MiniGrid-DoorKey-5x5-v0         10                 50          699.9
#                                                                             100        1274.2
#                          MiniGrid-Empty-8x8-v0           10                 50          159.5
#                                                                             100         159.5
#                          MiniGrid-LavaGapS7-v0           10                 50          206.0
#                                                                             100         835.1
#
#                                                                                             time
# model                    env                             n_episodes_setting max_steps
# Qwen/Qwen2.5-7B-Instruct MiniGrid-BlockedUnlockPickup-v0 10                 50         19.921641
#                                                                             100        38.069951
#                          MiniGrid-DoorKey-5x5-v0         10                 50         19.628164
#                                                                             100        36.108545
#                          MiniGrid-Empty-8x8-v0           10                 50          4.508998
#                                                                             100         4.486389
#                          MiniGrid-LavaGapS7-v0           10                 50          6.487166
#                                                                             100        23.363357

# %%
import shutil
shutil.make_archive("CS228", "zip", "CS 228")
# Out:
# '/root/CS228.zip'
